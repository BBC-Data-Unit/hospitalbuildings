# %% [markdown]
# # Analysing data on hospital buildings (ERIC)
#
# The Estates Returns Information Collection (ERIC) - data on NHS buildings including hospitals - is [published every October](https://digital.nhs.uk/data-and-information/publications/statistical/estates-returns-information-collection).
#
# This notebook details the code needed to:
#
# * Fetch the latest data
# * Fetch the data from 5 other years
# * Drill down to the columns that interest us (there are a *lot* of columns)
#
# The [page publishing the data](https://digital.nhs.uk/data-and-information/publications/statistical/estates-returns-information-collection/estates-return-information-collection-2016-17) notes:
#
# > Note: in 2019 we were advised of an error in Devonshire Partnership NHS Trust's submitted Oil Consumption figures. The correct figure for the aggregate site consumption is 40,798.8 kWh, rather than the reported 3,855 kWh.
#
# > Note: 7th September 2021: When the revalidated data was released, only the revised headline figures, report (containing trust, site and PFI level data) and data quality statement were made available (figures in the underlying data .csv files were not updated, although revised trust, site and PFI revised figures were available in the data tables). We apologise for any confusion caused and have now published revised .csv files to accompany the release products. These are clearly labelled below.
#
# For this analysis we are using the data marked "revalidation".

# %%
#import pandas for dealing with data
import pandas as pd
#we will need the math library too for detecting nan values
import math

# %% [markdown]
# ## Import the data
#
# Let's start by importing the earliest year's data.

# %%
sitedataurl = "https://files.digital.nhs.uk/F7/97436C/ERIC-201617-revalidation-Site%20Data-version2.csv"

# %%
#we get a UnicodeDecodeError error so add encoding thanks to https://stackoverflow.com/questions/18171739/unicodedecodeerror-when-reading-csv-file-in-pandas
sitedata1617 = pd.read_csv(sitedataurl, encoding = "ISO-8859-1")
sitedata1617.head(3)
# Out:
#   Trust Code                                Trust Name  \
# 0        R1A  WORCESTERSHIRE HEALTH AND CARE NHS TRUST
# 1        R1A  WORCESTERSHIRE HEALTH AND CARE NHS TRUST
# 2        R1A  WORCESTERSHIRE HEALTH AND CARE NHS TRUST
#
#                                 Commissioning Region Trust Type Site Code  \
# 0  MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION  COMMUNITY     AGGRE
# 1  MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION  COMMUNITY     R1A1P
# 2  MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION  COMMUNITY     R1A22
#
#                     Site Name  \
# 0              AGGREGATE SITE
# 1  EVESHAM COMMUNITY HOSPITAL
# 2  KEITH WINTER CLOSE MH UNIT
#
#                                           Site Type       Tenure Post Code  \
# 0                                    Aggregate Site          NaN   WR4 9RW
# 1       7. Community hospital (with inpatient beds)  1. Freehold  WR11 1JT
# 2  4. Mental Health (including Specialist services)  1. Freehold   B61 0EX
#
#   Estates and facilities finance costs (£)  ...  \
# 0                                2,728,686  ...
# 1                                  510,125  ...
# 2                                   74,098  ...
#
#   Cost of cleaning the occupied floor area not requiring regular cleaning (£)  \
# 0                                     Not Applicable
# 1                                                  0
# 2                                                399
#
#   Occupied floor area not requiring regular cleaning (%)  \
# 0                                     Not Applicable
# 1                                                  0
# 2                                                  1
#
#   Inpatient food service cost (£) Inpatient main meals requested (No.)  \
# 0                          14,458                                9,855
# 1                         202,047                               72,429
# 2                          17,660                               11,219
#
#   Cost of feeding one inpatient per day (inpatient meal day) (£)  \
# 0                                                4.4
# 1                                               8.37
# 2                                               4.72
#
#   Laundry and linen service cost (£) Pieces per annum (No.)  \
# 0                                198                    421
# 1                            228,381                200,797
# 2                              4,813                 10,000
#
#   Laundry and linen service used (Select) Portering service cost (£)  \
# 0                               3. Hybrid                     14,500
# 1                               3. Hybrid                    242,003
# 2              2. Full Service  In house                          0
#
#   Portering staff (WTE)
# 0                   0.6
# 1                     8
# 2                     0
#
# [3 rows x 128 columns]

# %% [markdown]
# ## Create a list of the keys we always want to use
#
# We want to keep the keys that we'll use in *all* analyses: those that identify the site, trust, and region. There are a lot of keys...

# %%
#how many keys are there?
len(sitedata1617.keys())
# Out:
# 128

# %%
#let's identify the ones we always want
print(sitedata1617.keys()[0:9])
#and store
keykeys = list(sitedata1617.keys()[0:9])
# Out:
# Index(['Trust Code', 'Trust Name', 'Commissioning Region', 'Trust Type',
#        'Site Code', 'Site Name', 'Site Type', 'Tenure', 'Post Code'],
#       dtype='object')

# %% [markdown]
# ## Create a subset focused on backlogs of repairs
#
# With so many columns, we need to drill down to those relevant to our analysis. We start with columns about the backlog of repairs. These all have the word 'backlog' in them, so we find the column headings with this code:

# %%
#loop through the keys and extract the ones with backlog in them
backlog_keys = [key for key in sitedata1617.keys() if 'backlog' in key.lower()]

# %%
#check the results
backlog_keys
# Out:
# ['Cost to eradicate high risk backlog (£)',
#  'Cost to eradicate significant risk backlog (£)',
#  'Cost to eradicate moderate risk backlog (£)',
#  'Cost to eradicate low risk backlog (£)']

# %%
#add those keys to the ones we've already stored
thesekeys = keykeys+backlog_keys
print(thesekeys)
# Out:
# ['Trust Code', 'Trust Name', 'Commissioning Region', 'Trust Type', 'Site Code', 'Site Name', 'Site Type', 'Tenure', 'Post Code', 'Cost to eradicate high risk backlog (£)', 'Cost to eradicate significant risk backlog (£)', 'Cost to eradicate moderate risk backlog (£)', 'Cost to eradicate low risk backlog (£)']

# %%
#we have to specify the indices to prevent an error
bothkeys = thesekeys[:9]+backlog_keys

# %%
#use those to extract a subset
backlogdf = sitedata1617[bothkeys]
backlogdf.head(3)
# Out:
#   Trust Code                                Trust Name  \
# 0        R1A  WORCESTERSHIRE HEALTH AND CARE NHS TRUST
# 1        R1A  WORCESTERSHIRE HEALTH AND CARE NHS TRUST
# 2        R1A  WORCESTERSHIRE HEALTH AND CARE NHS TRUST
#
#                                 Commissioning Region Trust Type Site Code  \
# 0  MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION  COMMUNITY     AGGRE
# 1  MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION  COMMUNITY     R1A1P
# 2  MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION  COMMUNITY     R1A22
#
#                     Site Name  \
# 0              AGGREGATE SITE
# 1  EVESHAM COMMUNITY HOSPITAL
# 2  KEITH WINTER CLOSE MH UNIT
#
#                                           Site Type       Tenure Post Code  \
# 0                                    Aggregate Site          NaN   WR4 9RW
# 1       7. Community hospital (with inpatient beds)  1. Freehold  WR11 1JT
# 2  4. Mental Health (including Specialist services)  1. Freehold   B61 0EX
#
#   Cost to eradicate high risk backlog (£)  \
# 0                                       0
# 1                                       0
# 2                                       0
#
#   Cost to eradicate significant risk backlog (£)  \
# 0                                        316,628
# 1                                      1,401,259
# 2                                              0
#
#   Cost to eradicate moderate risk backlog (£)  \
# 0                                   2,049,070
# 1                                   1,635,668
# 2                                      35,623
#
#   Cost to eradicate low risk backlog (£)
# 0                              1,218,122
# 1                              1,077,418
# 2                                 30,587

# %% [markdown]
# ### Create a pivot table on high risk costs
#
# If we try to pivot on total cost of backlogs by region, we hit two problems: the costs are stored as text, and there are non-numeric values in there.

# %%
backlogdf.pivot_table(index="Commissioning Region",
                      values="Cost to eradicate high risk backlog (£)",
                      aggfunc="sum")
# Out:
#                                                              Cost to eradicate high risk backlog (£)
# Commissioning Region
# Commissioning Region                                         Cost to eradicate high risk backlog (£)
# LONDON COMMISSIONING REGION                        01,602,560916,00016,784,6457,279,2992,462,4295...
# MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION  00000000000000Not Applicable120,0000170,00032,...
# NORTH OF ENGLAND COMMISSIONING REGION              000Not ApplicableNot Applicable00000050,000173...
# SOUTH OF ENGLAND COMMISSIONING REGION              4,50022,220Not Applicable60,68351,3500149,8007...

# %% [markdown]
# ### Filter out non-numbers and convert to integers
#
# We can see a problem with the results caused by the data being stored as strings, and including values like 'Not Applicable'. Let's fix that.

# %%
#filter to the rows where the condition is True
backlogdf[backlogdf['Cost to eradicate high risk backlog (£)'] == 'Not Applicable']
# Out:
#      Trust Code                                        Trust Name  \
# 15          R1C                                  SOLENT NHS TRUST
# 20          R1D             SHROPSHIRE COMMUNITY HEALTH NHS TRUST
# 48          R1K            LONDON NORTH WEST HEALTHCARE NHS TRUST
# 68          RAE  BRADFORD TEACHING HOSPITALS NHS FOUNDATION TRUST
# 69          RAE  BRADFORD TEACHING HOSPITALS NHS FOUNDATION TRUST
# ...         ...                                               ...
# 1179        RYY        KENT COMMUNITY HEALTH NHS FOUNDATION TRUST
# 1180        RYY        KENT COMMUNITY HEALTH NHS FOUNDATION TRUST
# 1181        RYY        KENT COMMUNITY HEALTH NHS FOUNDATION TRUST
# 1183        RYY        KENT COMMUNITY HEALTH NHS FOUNDATION TRUST
# 1184        RYY        KENT COMMUNITY HEALTH NHS FOUNDATION TRUST
#
#                                    Commissioning Region        Trust Type  \
# 15                SOUTH OF ENGLAND COMMISSIONING REGION         COMMUNITY
# 20    MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION         COMMUNITY
# 48                          LONDON COMMISSIONING REGION     ACUTE - LARGE
# 68                NORTH OF ENGLAND COMMISSIONING REGION  ACUTE - TEACHING
# 69                NORTH OF ENGLAND COMMISSIONING REGION  ACUTE - TEACHING
# ...                                                 ...               ...
# 1179              SOUTH OF ENGLAND COMMISSIONING REGION         COMMUNITY
# 1180              SOUTH OF ENGLAND COMMISSIONING REGION         COMMUNITY
# 1181              SOUTH OF ENGLAND COMMISSIONING REGION         COMMUNITY
# 1183              SOUTH OF ENGLAND COMMISSIONING REGION         COMMUNITY
# 1184              SOUTH OF ENGLAND COMMISSIONING REGION         COMMUNITY
#
#      Site Code                             Site Name  \
# 15       R1C34            ROYAL SOUTH HANTS HOSPITAL
# 20       R1D21                       LUDLOW HOSPITAL
# 48       R1K23  WILLESDEN CENTRE FOR HEALTH AND CARE
# 68       RAE3A                         WESTWOOD PARK
# 69       RAE5H   WESTBOURNE GREEN COMMUNITY HOSPITAL
# ...        ...                                   ...
# 1179     RYYCH                     VICTORIA HOSPITAL
# 1180     RYYCM       WHITSTABLE & TANKERTON HOSPITAL
# 1181     RYYD4                   EDENBRIDGE HOSPITAL
# 1183     RYYD9                    SEVENOAKS HOSPITAL
# 1184     RYYDC            TONBRIDGE COTTAGE HOSPITAL
#
#                                         Site Type  \
# 15    7. Community hospital (with inpatient beds)
# 20    7. Community hospital (with inpatient beds)
# 48    7. Community hospital (with inpatient beds)
# 68    7. Community hospital (with inpatient beds)
# 69    7. Community hospital (with inpatient beds)
# ...                                           ...
# 1179  7. Community hospital (with inpatient beds)
# 1180  7. Community hospital (with inpatient beds)
# 1181  7. Community hospital (with inpatient beds)
# 1183  7. Community hospital (with inpatient beds)
# 1184  7. Community hospital (with inpatient beds)
#
#                                     Tenure Post Code  \
# 15    7. Leased from NHS Property Services  SO14 0YG
# 20    7. Leased from NHS Property Services   SY8 1QX
# 48    7. Leased from NHS Property Services  NW10 3RY
# 68    7. Leased from NHS Property Services  BD6  3NL
# 69    7. Leased from NHS Property Services   BD8 8RA
# ...                                    ...       ...
# 1179  7. Leased from NHS Property Services  CT14 9UA
# 1180  7. Leased from NHS Property Services   CT5 2HN
# 1181  7. Leased from NHS Property Services   TN8 5DA
# 1183  7. Leased from NHS Property Services  TN13 3PG
# 1184  7. Leased from NHS Property Services  TN11 0NE
#
#      Cost to eradicate high risk backlog (£)  \
# 15                            Not Applicable
# 20                            Not Applicable
# 48                            Not Applicable
# 68                            Not Applicable
# 69                            Not Applicable
# ...                                      ...
# 1179                          Not Applicable
# 1180                          Not Applicable
# 1181                          Not Applicable
# 1183                          Not Applicable
# 1184                          Not Applicable
#
#      Cost to eradicate significant risk backlog (£)  \
# 15                                   Not Applicable
# 20                                   Not Applicable
# 48                                   Not Applicable
# 68                                   Not Applicable
# 69                                   Not Applicable
# ...                                             ...
# 1179                                 Not Applicable
# 1180                                 Not Applicable
# 1181                                 Not Applicable
# 1183                                 Not Applicable
# 1184                                 Not Applicable
#
#      Cost to eradicate moderate risk backlog (£)  \
# 15                                Not Applicable
# 20                                Not Applicable
# 48                                Not Applicable
# 68                                Not Applicable
# 69                                Not Applicable
# ...                                          ...
# 1179                              Not Applicable
# 1180                              Not Applicable
# 1181                              Not Applicable
# 1183                              Not Applicable
# 1184                              Not Applicable
#
#      Cost to eradicate low risk backlog (£)
# 15                           Not Applicable
# 20                           Not Applicable
# 48                           Not Applicable
# 68                           Not Applicable
# 69                           Not Applicable
# ...                                     ...
# 1179                         Not Applicable
# 1180                         Not Applicable
# 1181                         Not Applicable
# 1183                         Not Applicable
# 1184                         Not Applicable
#
# [161 rows x 13 columns]

# %% [markdown]
# There's also a problem with a line which repeats the column headers.

# %%
#filter to the rows where the condition is True
backlogdf[backlogdf['Cost to eradicate high risk backlog (£)'] == 'Cost to eradicate high risk backlog (£)']
# Out:
#       Trust Code  Trust Name  Commissioning Region  Trust Type  Site Code  \
# 1215  Trust Code  Trust Name  Commissioning Region  Trust Type  Site Code
#
#       Site Name  Site Type  Tenure  Post Code  \
# 1215  Site Name  Site Type  Tenure  Post Code
#
#       Cost to eradicate high risk backlog (£)  \
# 1215  Cost to eradicate high risk backlog (£)
#
#       Cost to eradicate significant risk backlog (£)  \
# 1215  Cost to eradicate significant risk backlog (£)
#
#       Cost to eradicate moderate risk backlog (£)  \
# 1215  Cost to eradicate moderate risk backlog (£)
#
#       Cost to eradicate low risk backlog (£)
# 1215  Cost to eradicate low risk backlog (£)

# %% [markdown]
# We can calculate how many rows we *should* end up with once those as removed.

# %%
#Calculate how many rows we should end up with when the 161 matching ones are removed
#start with the number of rows in the dataframe
print(len(backlogdf))
#how many when filtered
print(len(backlogdf[backlogdf['Cost to eradicate high risk backlog (£)'] == 'Not Applicable']))
#subtract one from the other
print(1216-161)
# Out:
# 1216
# 161
# 1055

# %% [markdown]
# Then apply a filter to remove the rows we don't want.

# %%
#filter to the rows where the condition is True
#.index converts that list of T/F to a list of indices
backlog_filtered = backlogdf.drop(backlogdf[backlogdf['Cost to eradicate high risk backlog (£)'] == 'Not Applicable'].index)
#remove the extra row of headers too - this time inplace
backlog_filtered.drop(backlog_filtered[backlog_filtered['Cost to eradicate high risk backlog (£)'] == 'Cost to eradicate high risk backlog (£)'].index,
                      inplace = True)
backlog_filtered
# Out:
#      Trust Code                                      Trust Name  \
# 0           R1A        WORCESTERSHIRE HEALTH AND CARE NHS TRUST
# 1           R1A        WORCESTERSHIRE HEALTH AND CARE NHS TRUST
# 2           R1A        WORCESTERSHIRE HEALTH AND CARE NHS TRUST
# 3           R1A        WORCESTERSHIRE HEALTH AND CARE NHS TRUST
# 4           R1A        WORCESTERSHIRE HEALTH AND CARE NHS TRUST
# ...         ...                                             ...
# 1210        TAJ  BLACK COUNTRY PARTNERSHIP NHS FOUNDATION TRUST
# 1211        TAJ  BLACK COUNTRY PARTNERSHIP NHS FOUNDATION TRUST
# 1212        TAJ  BLACK COUNTRY PARTNERSHIP NHS FOUNDATION TRUST
# 1213        NaN                                             NaN
# 1214        NaN                                             NaN
#
#                                    Commissioning Region  Trust Type Site Code  \
# 0     MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION   COMMUNITY     AGGRE
# 1     MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION   COMMUNITY     R1A1P
# 2     MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION   COMMUNITY     R1A22
# 3     MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION   COMMUNITY     R1A49
# 4     MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION   COMMUNITY     R1AAN
# ...                                                 ...         ...       ...
# 1210  MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION  CARE TRUST     TAJ52
# 1211  MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION  CARE TRUST     TAJ54
# 1212  MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION  CARE TRUST     TAJ55
# 1213                                                NaN         NaN       NaN
# 1214                                                NaN         NaN       NaN
#
#                        Site Name  \
# 0                 AGGREGATE SITE
# 1     EVESHAM COMMUNITY HOSPITAL
# 2     KEITH WINTER CLOSE MH UNIT
# 3             HILL CREST MH UNIT
# 4     TENBURY COMMUNITY HOSPITAL
# ...                          ...
# 1210               PENN HOSPITAL
# 1211         RIDGE HILL HOSPITAL
# 1212                  DAISY BANK
# 1213                         NaN
# 1214                         NaN
#
#                                              Site Type  \
# 0                                       Aggregate Site
# 1          7. Community hospital (with inpatient beds)
# 2     4. Mental Health (including Specialist services)
# 3     4. Mental Health (including Specialist services)
# 4          7. Community hospital (with inpatient beds)
# ...                                                ...
# 1210  4. Mental Health (including Specialist services)
# 1211                          5. Learning Disabilities
# 1212                          5. Learning Disabilities
# 1213                                               NaN
# 1214                                               NaN
#
#                                         Tenure Post Code  \
# 0                                          NaN   WR4 9RW
# 1                                  1. Freehold  WR11 1JT
# 2                                  1. Freehold   B61 0EX
# 3                        4. SLA/lease from NHS   B98 7WG
# 4                                  1. Freehold  WR15 8AF
# ...                                        ...       ...
# 1210                               1. Freehold   WV4 5HN
# 1211  6. Local Investment Finance Trust (LIFT)   DY8 5ST
# 1212                               1. Freehold   WS5 3DY
# 1213                                       NaN       NaN
# 1214                                       NaN       NaN
#
#      Cost to eradicate high risk backlog (£)  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ...                                      ...
# 1210                                       0
# 1211                                       0
# 1212                                       0
# 1213                                     NaN
# 1214                                     NaN
#
#      Cost to eradicate significant risk backlog (£)  \
# 0                                           316,628
# 1                                         1,401,259
# 2                                                 0
# 3                                                 0
# 4                                             4,878
# ...                                             ...
# 1210                                        284,034
# 1211                                              0
# 1212                                         32,382
# 1213                                            NaN
# 1214                                            NaN
#
#      Cost to eradicate moderate risk backlog (£)  \
# 0                                      2,049,070
# 1                                      1,635,668
# 2                                         35,623
# 3                                              0
# 4                                        175,215
# ...                                          ...
# 1210                                     135,650
# 1211                                           0
# 1212                                      22,000
# 1213                                         NaN
# 1214                                         NaN
#
#      Cost to eradicate low risk backlog (£)
# 0                                 1,218,122
# 1                                 1,077,418
# 2                                    30,587
# 3                                    16,695
# 4                                   116,636
# ...                                     ...
# 1210                                165,600
# 1211                                      0
# 1212                                      0
# 1213                                    NaN
# 1214                                    NaN
#
# [1054 rows x 13 columns]

# %% [markdown]
# ### Try the pivot table again
#
# Now we've removed the not applicable fields, will the pivot table work?

# %%
backlog_filtered.pivot_table(index="Commissioning Region",
                      values="Cost to eradicate high risk backlog (£)",
                      aggfunc="sum")
# Out:
#                                                              Cost to eradicate high risk backlog (£)
# Commissioning Region
# LONDON COMMISSIONING REGION                        01,602,560916,00016,784,6457,279,2992,462,4295...
# MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION  00000000000000120,0000170,00032,00054,411296,4...
# NORTH OF ENGLAND COMMISSIONING REGION              00000000050,000173,84200354,108000002,313,5850...
# SOUTH OF ENGLAND COMMISSIONING REGION              4,50022,22060,68351,3500149,800764,58925,00000...

# %% [markdown]
# ### Filter out NaN values (floats)
#
# We have some `nan` values in there. These read as floats so we can filter on that to see if the rows can be safely removed.

# %%
#create a filter that looks for floats (NaN values)
backlog_filtered[[type(i) == float for i in backlog_filtered["Cost to eradicate high risk backlog (£)"]]]
# Out:
#      Trust Code Trust Name Commissioning Region Trust Type Site Code  \
# 1213        NaN        NaN                  NaN        NaN       NaN
# 1214        NaN        NaN                  NaN        NaN       NaN
#
#      Site Name Site Type Tenure Post Code  \
# 1213       NaN       NaN    NaN       NaN
# 1214       NaN       NaN    NaN       NaN
#
#      Cost to eradicate high risk backlog (£)  \
# 1213                                     NaN
# 1214                                     NaN
#
#      Cost to eradicate significant risk backlog (£)  \
# 1213                                            NaN
# 1214                                            NaN
#
#      Cost to eradicate moderate risk backlog (£)  \
# 1213                                         NaN
# 1214                                         NaN
#
#      Cost to eradicate low risk backlog (£)
# 1213                                    NaN
# 1214                                    NaN

# %% [markdown]
# They can.

# %%
#filter to the rows where the condition is True
backlog_filtered = backlogdf.drop(backlogdf[[type(i) == float for i in backlogdf["Cost to eradicate high risk backlog (£)"]]].index)
#.index converts that list of T/F to a list of indices
backlog_filtered = backlog_filtered.drop(backlog_filtered[backlog_filtered['Cost to eradicate high risk backlog (£)'] == 'Not Applicable'].index)
#remove the extra row of headers too - this time inplace
backlog_filtered = backlog_filtered.drop(backlog_filtered[backlog_filtered['Cost to eradicate high risk backlog (£)'] == 'Cost to eradicate high risk backlog (£)'].index)
backlog_filtered
# Out:
#      Trust Code                                      Trust Name  \
# 0           R1A        WORCESTERSHIRE HEALTH AND CARE NHS TRUST
# 1           R1A        WORCESTERSHIRE HEALTH AND CARE NHS TRUST
# 2           R1A        WORCESTERSHIRE HEALTH AND CARE NHS TRUST
# 3           R1A        WORCESTERSHIRE HEALTH AND CARE NHS TRUST
# 4           R1A        WORCESTERSHIRE HEALTH AND CARE NHS TRUST
# ...         ...                                             ...
# 1208        TAJ  BLACK COUNTRY PARTNERSHIP NHS FOUNDATION TRUST
# 1209        TAJ  BLACK COUNTRY PARTNERSHIP NHS FOUNDATION TRUST
# 1210        TAJ  BLACK COUNTRY PARTNERSHIP NHS FOUNDATION TRUST
# 1211        TAJ  BLACK COUNTRY PARTNERSHIP NHS FOUNDATION TRUST
# 1212        TAJ  BLACK COUNTRY PARTNERSHIP NHS FOUNDATION TRUST
#
#                                    Commissioning Region  Trust Type Site Code  \
# 0     MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION   COMMUNITY     AGGRE
# 1     MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION   COMMUNITY     R1A1P
# 2     MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION   COMMUNITY     R1A22
# 3     MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION   COMMUNITY     R1A49
# 4     MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION   COMMUNITY     R1AAN
# ...                                                 ...         ...       ...
# 1208  MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION  CARE TRUST     TAJ11
# 1209  MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION  CARE TRUST     TAJ20
# 1210  MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION  CARE TRUST     TAJ52
# 1211  MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION  CARE TRUST     TAJ54
# 1212  MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION  CARE TRUST     TAJ55
#
#                        Site Name  \
# 0                 AGGREGATE SITE
# 1     EVESHAM COMMUNITY HOSPITAL
# 2     KEITH WINTER CLOSE MH UNIT
# 3             HILL CREST MH UNIT
# 4     TENBURY COMMUNITY HOSPITAL
# ...                          ...
# 1208         HEATH LANE HOSPITAL
# 1209      HALLAM STREET HOSPITAL
# 1210               PENN HOSPITAL
# 1211         RIDGE HILL HOSPITAL
# 1212                  DAISY BANK
#
#                                              Site Type  \
# 0                                       Aggregate Site
# 1          7. Community hospital (with inpatient beds)
# 2     4. Mental Health (including Specialist services)
# 3     4. Mental Health (including Specialist services)
# 4          7. Community hospital (with inpatient beds)
# ...                                                ...
# 1208        6. Mental Health and Learning Disabilities
# 1209                         3. Mixed service hospital
# 1210  4. Mental Health (including Specialist services)
# 1211                          5. Learning Disabilities
# 1212                          5. Learning Disabilities
#
#                                                 Tenure Post Code  \
# 0                                                  NaN   WR4 9RW
# 1                                          1. Freehold  WR11 1JT
# 2                                          1. Freehold   B61 0EX
# 3                                4. SLA/lease from NHS   B98 7WG
# 4                                          1. Freehold  WR15 8AF
# ...                                                ...       ...
# 1208                                       1. Freehold  B71  2BG
# 1209  2. Whole site - Private Finance Initiative (PFI)  B71  4NH
# 1210                                       1. Freehold   WV4 5HN
# 1211          6. Local Investment Finance Trust (LIFT)   DY8 5ST
# 1212                                       1. Freehold   WS5 3DY
#
#      Cost to eradicate high risk backlog (£)  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ...                                      ...
# 1208                                  46,428
# 1209                                       0
# 1210                                       0
# 1211                                       0
# 1212                                       0
#
#      Cost to eradicate significant risk backlog (£)  \
# 0                                           316,628
# 1                                         1,401,259
# 2                                                 0
# 3                                                 0
# 4                                             4,878
# ...                                             ...
# 1208                                         87,195
# 1209                                              0
# 1210                                        284,034
# 1211                                              0
# 1212                                         32,382
#
#      Cost to eradicate moderate risk backlog (£)  \
# 0                                      2,049,070
# 1                                      1,635,668
# 2                                         35,623
# 3                                              0
# 4                                        175,215
# ...                                          ...
# 1208                                      16,400
# 1209                                           0
# 1210                                     135,650
# 1211                                           0
# 1212                                      22,000
#
#      Cost to eradicate low risk backlog (£)
# 0                                 1,218,122
# 1                                 1,077,418
# 2                                    30,587
# 3                                    16,695
# 4                                   116,636
# ...                                     ...
# 1208                                 10,000
# 1209                                      0
# 1210                                165,600
# 1211                                      0
# 1212                                      0
#
# [1052 rows x 13 columns]

# %% [markdown]
# ### Clean the commas from the figures so they can be converted to numbers
#
# Now we should be able to convert the remaining strings to numbers - but we need to remove the commas first.

# %%
#create a new list
highriskcost_int = []
#loop through the strings
for i in backlog_filtered["Cost to eradicate high risk backlog (£)"]:
  #print(i)
  #if it's a string, which they all should be now
  if type(i) == str:
    #replace the comma, otherwise it won't convert to an integer
    newfigure = int(i.replace(',',''))
    #add to the list
    highriskcost_int.append(int(newfigure))
  else:
    print('HUH', type(i))
    print(math.isnan(i))

# %%
#is it the same length as the dataframe?
len(highriskcost_int) == len(backlog_filtered)
# Out:
# True

# %%
#check we can add it back into the dataframe
backlog_filtered['highriskcost_int'] = highriskcost_int

# %% [markdown]
# We can now check the total of that - and see if it matches the same analysis performed in an Excel spreadsheet (947110283).

# %%
#check the total
sum(highriskcost_int)
# Out:
# 947110283

# %% [markdown]
# ## Pivot on total cost of backlog of high risk repairs
#
# Now we can try that pivot again.

# %%
backlog_filtered.pivot_table(index="Commissioning Region",
                      values="highriskcost_int",
                      aggfunc="sum")
# Out:
#                                                    highriskcost_int
# Commissioning Region
# LONDON COMMISSIONING REGION                               525903775
# MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION         194626219
# NORTH OF ENGLAND COMMISSIONING REGION                     103329921
# SOUTH OF ENGLAND COMMISSIONING REGION                     123250368

# %% [markdown]
# These values also match an analysis in Excel.
#
# We can do the same pivot table by trust, too.

# %%
backlog_filtered.pivot_table(index="Trust Name",
                      values="highriskcost_int",
                      aggfunc="sum")
# Out:
#                                                     highriskcost_int
# Trust Name
# 2GETHER NHS FOUNDATION TRUST                                 1664000
# 5 BOROUGHS PARTNERSHIP NHS FOUNDATION TRUST                        0
# AINTREE UNIVERSITY HOSPITAL NHS FOUNDATION TRUST                   0
# AIREDALE NHS FOUNDATION TRUST                                 385000
# ALDER HEY CHILDRENS NHS FOUNDATION TRUST                       50000
# ...                                                              ...
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST                 0
# WYE VALLEY NHS TRUST                                        14900000
# YEOVIL DISTRICT HOSPITAL NHS FOUNDATION TRUST                      0
# YORK TEACHING HOSPITAL NHS FOUNDATION TRUST                  2495085
# YORKSHIRE AMBULANCE SERVICE NHS TRUST                          88950
#
# [236 rows x 1 columns]

# %% [markdown]
# ## Fetch the other years (create some functions)
#
# Now to compare that with other years.

# %%
#define a function, it takes one argument - the url of the CSV
def backlogdataonly(csvurl):
  #read in the CSV
  sitedata = pd.read_csv(csvurl, encoding = "ISO-8859-1")
  #store the first 9 column names
  keykeys = list(sitedata.keys()[0:9])
  print(keykeys)
  #loop through the keys and extract the ones with backlog in them
  backlog_keys = [key for key in sitedata.keys() if 'backlog' in key.lower()]
  #add those keys to the ones we've already stored
  bothkeys = keykeys[:9]+backlog_keys
  print(bothkeys)
  #use those to extract a subset
  backlogdf = sitedata[bothkeys]
  #filter to the rows where the condition is True
  backlog_filtered = backlogdf.drop(backlogdf[[type(i) == float for i in backlogdf["Cost to eradicate high risk backlog (£)"]]].index)
  #.index converts that list of T/F to a list of indices
  backlog_filtered = backlog_filtered.drop(backlog_filtered[backlog_filtered['Cost to eradicate high risk backlog (£)'] == 'Not Applicable'].index)
  #remove the extra row of headers too - this time inplace
  backlog_filtered = backlog_filtered.drop(backlog_filtered[backlog_filtered['Cost to eradicate high risk backlog (£)'] == 'Cost to eradicate high risk backlog (£)'].index)
  #return the resulting dataframe to whatever called the function
  return(backlog_filtered)

# %%
def cleannumbers(column):
  #create a new list
  column_as_ints = []
  #loop through the strings
  for i in column:
    #print(i)
    #if it's a string, which they all should be now
    if type(i) == str:
      #replace the comma, otherwise it won't convert to an integer
      newfigure = int(i.replace(',',''))
      #add to the list
      column_as_ints.append(int(newfigure))
    else:
      print('HUH', type(i))
      print(math.isnan(i))
  return(column_as_ints)

# %%
#test the function
backlogdf = backlogdataonly("https://files.digital.nhs.uk/A8/188D99/ERIC-201718-SiteData.csv")
#test the second function
backlogdf['high_risk_backlog_cost'] = cleannumbers(backlogdf['Cost to eradicate high risk backlog (£)'])
#show the results
backlogdf
# Out:
#      Trust Code                                      Trust Name  \
# 0           R0A      MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 1           R0A      MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 2           R0A      MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 3           R0A      MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 4           R0A      MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# ...         ...                                             ...
# 1154        TAJ  BLACK COUNTRY PARTNERSHIP NHS FOUNDATION TRUST
# 1155        TAJ  BLACK COUNTRY PARTNERSHIP NHS FOUNDATION TRUST
# 1156        TAJ  BLACK COUNTRY PARTNERSHIP NHS FOUNDATION TRUST
# 1157        TAJ  BLACK COUNTRY PARTNERSHIP NHS FOUNDATION TRUST
# 1158        TAJ  BLACK COUNTRY PARTNERSHIP NHS FOUNDATION TRUST
#
#                                    Commissioning Region        Trust Type  \
# 0                 NORTH OF ENGLAND COMMISSIONING REGION  ACUTE - TEACHING
# 1                 NORTH OF ENGLAND COMMISSIONING REGION  ACUTE - TEACHING
# 2                 NORTH OF ENGLAND COMMISSIONING REGION  ACUTE - TEACHING
# 3                 NORTH OF ENGLAND COMMISSIONING REGION  ACUTE - TEACHING
# 4                 NORTH OF ENGLAND COMMISSIONING REGION  ACUTE - TEACHING
# ...                                                 ...               ...
# 1154  MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION        CARE TRUST
# 1155  MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION        CARE TRUST
# 1156  MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION        CARE TRUST
# 1157  MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION        CARE TRUST
# 1158  MIDLANDS AND EAST OF ENGLAND COMMISSIONING REGION        CARE TRUST
#
#      Site Code                              Site Name  \
# 0        AGGRE                         AGGREGATE SITE
# 1        R0A01                            ISLAND SITE
# 2        R0A07                   WYTHENSHAWE HOSPITAL
# 3        R0A09              TRAFFORD GENERAL HOSPITAL
# 4        R0A47  DERMOTT MURPHY CLOSE - LONG STAY UNIT
# ...        ...                                    ...
# 1154     TAJ07                 EDWARD STREET HOSPITAL
# 1155     TAJ11                    HEATH LANE HOSPITAL
# 1156     TAJ20                 HALLAM STREET HOSPITAL
# 1157     TAJ52                          PENN HOSPITAL
# 1158     TAJ55                             DAISY BANK
#
#                                              Site Type  \
# 0                                       Aggregate Site
# 1                            1. General acute hospital
# 2                            1. General acute hospital
# 3                            1. General acute hospital
# 4                                   8. Other inpatient
# ...                                                ...
# 1154  4. Mental Health (including Specialist services)
# 1155        6. Mental Health and Learning Disabilities
# 1156        6. Mental Health and Learning Disabilities
# 1157  4. Mental Health (including Specialist services)
# 1158                          5. Learning Disabilities
#
#                                                 Tenure Leasehold Type  \
# 0                                                  NaN            NaN
# 1     2. Whole site - Private Finance Initiative (PFI)            NaN
# 2     2. Whole site - Private Finance Initiative (PFI)            NaN
# 3                                          1. Freehold            NaN
# 4                                          1. Freehold            NaN
# ...                                                ...            ...
# 1154                                       1. Freehold            NaN
# 1155                                       1. Freehold            NaN
# 1156  2. Whole site - Private Finance Initiative (PFI)            NaN
# 1157                                       1. Freehold            NaN
# 1158                                       1. Freehold            NaN
#
#      Cost to eradicate high risk backlog (£)  \
# 0                                      1,858
# 1                                        200
# 2                                    232,177
# 3                                  4,440,391
# 4                                          0
# ...                                      ...
# 1154                                 130,900
# 1155                                       0
# 1156                                       0
# 1157                                       0
# 1158                                       0
#
#      Cost to eradicate significant risk backlog (£)  \
# 0                                                 0
# 1                                           417,946
# 2                                        14,598,996
# 3                                         3,561,412
# 4                                                 0
# ...                                             ...
# 1154                                         38,200
# 1155                                          4,800
# 1156                                              0
# 1157                                         38,350
# 1158                                         14,300
#
#      Cost to eradicate moderate risk backlog (£)  \
# 0                                        421,219
# 1                                      4,292,709
# 2                                      6,988,717
# 3                                        695,601
# 4                                              0
# ...                                          ...
# 1154                                      64,040
# 1155                                           0
# 1156                                           0
# 1157                                     194,609
# 1158                                      10,410
#
#      Cost to eradicate low risk backlog (£)  high_risk_backlog_cost
# 0                                    43,534                    1858
# 1                                 1,769,794                     200
# 2                                 5,370,371                  232177
# 3                                 6,175,566                 4440391
# 4                                         0                       0
# ...                                     ...                     ...
# 1154                                219,528                  130900
# 1155                                 23,875                       0
# 1156                                 26,262                       0
# 1157                                278,156                       0
# 1158                                 83,692                       0
#
# [1012 rows x 14 columns]

# %% [markdown]
# ### Fixing 21/22
#
# This works on each of the last 5 years' data apart from 21/22. This is because the column heading is slightly different: `'Cost to eradicate high risk backlog (Â£)'` instead of `'Cost to eradicate high risk backlog (£)'`
#
# A similar problem causes the first column to be treated separately, so we clean that too below.

# %%
backlogdataonly('https://files.digital.nhs.uk/72/97A33E/ERIC%20-%20202122%20-%20Site%20data.csv')
# Out:
# ['ï»¿Trust Code', 'Trust Name', 'Commissioning Region', 'Trust Type', 'Status', 'Site Code', 'Site Name', 'Site Type', 'Tenure']
# ['ï»¿Trust Code', 'Trust Name', 'Commissioning Region', 'Trust Type', 'Status', 'Site Code', 'Site Name', 'Site Type', 'Tenure', 'Cost to eradicate high risk backlog (Â£)', 'Cost to eradicate significant risk backlog (Â£)', 'Cost to eradicate moderate risk backlog (Â£)', 'Cost to eradicate low risk backlog (Â£)', 'Percentage of GIA surveyed using risk adjusted backlog guidance (Select)', 'Methodology used to review costs to eradicate backlog (Select)', 'Methodology used to review costs to eradicate backlog - Reason (Notes)', 'Investment to reduce backlog maintenance - Critical Infrastructure Risk (Â£)', 'Investment to reduce backlog maintenance - non Critical Infrastructure Risk (Â£)']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cost to eradicate high risk backlog (£)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-fb0ac7e932b9> in <cell line: 1>()
# ----> 1 backlogdataonly('https://files.digital.nhs.uk/72/97A33E/ERIC%20-%20202122%20-%20Site%20data.csv')
#
# <ipython-input-7-4e4ced3fe78f> in backlogdataonly(csvurl)
#      14   backlogdf = sitedata[bothkeys]
#      15   #filter to the rows where the condition is True
# ---> 16   backlog_filtered = backlogdf.drop(backlogdf[[type(i) == float for i in backlogdf["Cost to eradicate high risk backlog (£)"]]].index)
#      17   #.index converts that list of T/F to a list of indices
#      18   backlog_filtered = backlog_filtered.drop(backlog_filtered[backlog_filtered['Cost to eradicate high risk backlog (£)'] == 'Not Applicable'].index)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Cost to eradicate high risk backlog (£)'

# %% [markdown]
# ### Reshape wide to long
#
# Let's try to fix it by reshaping the dataframe first from wide to long before we filter on that column (we can then filter on the 'value' column with 'measure' storing the column names)

# %%
sitedata = pd.read_csv('https://files.digital.nhs.uk/72/97A33E/ERIC%20-%20202122%20-%20Site%20data.csv', encoding = "ISO-8859-1")
#store the first 9 column names
keykeys = list(sitedata.keys()[0:9])
print(keykeys)
#loop through the keys and extract the ones with backlog in them
backlog_keys = [key for key in sitedata.keys() if 'backlog' in key.lower()]
#add those keys to the ones we've already stored
bothkeys = keykeys[:9]+backlog_keys
print(bothkeys)
#use those to extract a subset
backlogdf = sitedata[bothkeys]

#reshape from wide to long
longversion = pd.melt(backlogdf, id_vars=list(sitedata.keys()[0:9]),var_name='measure', value_name='values')
print(longversion)
#filter to the rows where the condition is True
backlog_filtered = longversion.drop(longversion[[type(i) == float for i in longversion["values"]]].index)
#.index converts that list of T/F to a list of indices
backlog_filtered = backlog_filtered.drop(backlog_filtered[backlog_filtered['values'] == 'Not Applicable'].index)
#remove the extra row of headers too - this time inplace
backlog_filtered = backlog_filtered.drop(backlog_filtered[backlog_filtered['values'] == 'Cost to eradicate high risk backlog (£)'].index)
#return the resulting dataframe to whatever called the function
#return(backlog_filtered)

#rename columns
if 'Trust Code' in backlogdf.keys()[0]:
  replacename = backlogdf.keys()[0]
  backlogdf = backlogdf.rename(columns={replacename: 'Trust Code'})
print(backlogdf.keys())
#print(backlog_filtered)
# Out:
# ['ï»¿Trust Code', 'Trust Name', 'Commissioning Region', 'Trust Type', 'Status', 'Site Code', 'Site Name', 'Site Type', 'Tenure']
# ['ï»¿Trust Code', 'Trust Name', 'Commissioning Region', 'Trust Type', 'Status', 'Site Code', 'Site Name', 'Site Type', 'Tenure', 'Cost to eradicate high risk backlog (Â£)', 'Cost to eradicate significant risk backlog (Â£)', 'Cost to eradicate moderate risk backlog (Â£)', 'Cost to eradicate low risk backlog (Â£)', 'Percentage of GIA surveyed using risk adjusted backlog guidance (Select)', 'Methodology used to review costs to eradicate backlog (Select)', 'Methodology used to review costs to eradicate backlog - Reason (Notes)', 'Investment to reduce backlog maintenance - Critical Infrastructure Risk (Â£)', 'Investment to reduce backlog maintenance - non Critical Infrastructure Risk (Â£)']
#       ï»¿Trust Code                                     Trust Name  \
# 0               R0A     MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 1               R0A     MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 2               R0A     MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 3               R0A     MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 4               R0A     MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# ...             ...                                            ...
# 25717           TAJ  BLACK COUNTRY HEALTHCARE NHS FOUNDATION TRUST
# 25718           TAJ  BLACK COUNTRY HEALTHCARE NHS FOUNDATION TRUST
# 25719           TAJ  BLACK COUNTRY HEALTHCARE NHS FOUNDATION TRUST
# 25720           TAJ  BLACK COUNTRY HEALTHCARE NHS FOUNDATION TRUST
# 25721           TAJ  BLACK COUNTRY HEALTHCARE NHS FOUNDATION TRUST
#
#                   Commissioning Region                             Trust Type  \
# 0      NORTH WEST COMMISSIONING REGION                       ACUTE - TEACHING
# 1      NORTH WEST COMMISSIONING REGION                       ACUTE - TEACHING
# 2      NORTH WEST COMMISSIONING REGION                       ACUTE - TEACHING
# 3      NORTH WEST COMMISSIONING REGION                       ACUTE - TEACHING
# 4      NORTH WEST COMMISSIONING REGION                       ACUTE - TEACHING
# ...                                ...                                    ...
# 25717    MIDLANDS COMMISSIONING REGION  MENTAL HEALTH AND LEARNING DISABILITY
# 25718    MIDLANDS COMMISSIONING REGION  MENTAL HEALTH AND LEARNING DISABILITY
# 25719    MIDLANDS COMMISSIONING REGION  MENTAL HEALTH AND LEARNING DISABILITY
# 25720    MIDLANDS COMMISSIONING REGION  MENTAL HEALTH AND LEARNING DISABILITY
# 25721    MIDLANDS COMMISSIONING REGION  MENTAL HEALTH AND LEARNING DISABILITY
#
#           Status Site Code                                    Site Name  \
# 0      Committed     C5Y2X                     LANCE BURN HEALTH CENTRE
# 1      Committed     C9Y7X                                CRESCENT BANK
# 2      Committed     E4D1L                          WYTHENSHAWE OFFICES
# 3      Committed     I0Z5L  MEDICAL RECORD 2, ASHBURY'S BUSINESS CENTRE
# 4      Committed     I5U0V   MEDICAL RECORDS 1, DELTA INDUSTRIAL ESTATE
# ...          ...       ...                                          ...
# 25717  Committed     TAJ94                           THE POPLARS CENTRE
# 25718  Committed     TAJ95                                    HALESVIEW
# 25719  Committed     TAJ96                                   HILL HOUSE
# 25720  Committed     TAJ98                                    CANALSIDE
# 25721  Committed    TAJORS                       OTHER REPORTABLE SITES
#
#                                            Site Type  \
# 0                                      Non inpatient
# 1                                      Non inpatient
# 2                                      Non inpatient
# 3                                      Non inpatient
# 4                                      Non inpatient
# ...                                              ...
# 25717  Mental Health (including Specialist services)
# 25718                                  Non inpatient
# 25719  Mental Health (including Specialist services)
# 25720                                  Non inpatient
# 25721                          Other Reportable Site
#
#                                                   Tenure  \
# 0                   7. Leased from NHS Property Services
# 1                   7. Leased from NHS Property Services
# 2                   7. Leased from NHS Property Services
# 3      9. Leased from commercial organisation - lease...
# 4      9. Leased from commercial organisation - lease...
# ...                                                  ...
# 25717                    5. SLA/lease from public sector
# 25718                                        1. Freehold
# 25719                                        1. Freehold
# 25720  9. Leased from commercial organisation - lease...
# 25721                                                NaN
#
#                                                  measure          values
# 0               Cost to eradicate high risk backlog (Â£)  Not Applicable
# 1               Cost to eradicate high risk backlog (Â£)  Not Applicable
# 2               Cost to eradicate high risk backlog (Â£)  Not Applicable
# 3               Cost to eradicate high risk backlog (Â£)               0
# 4               Cost to eradicate high risk backlog (Â£)               0
# ...                                                  ...             ...
# 25717  Investment to reduce backlog maintenance - non...  Not Applicable
# 25718  Investment to reduce backlog maintenance - non...               0
# 25719  Investment to reduce backlog maintenance - non...               0
# 25720  Investment to reduce backlog maintenance - non...  Not Applicable
# 25721  Investment to reduce backlog maintenance - non...               0
#
# [25722 rows x 11 columns]
# Index(['Trust Code', 'Trust Name', 'Commissioning Region', 'Trust Type',
#        'Status', 'Site Code', 'Site Name', 'Site Type', 'Tenure',
#        'Cost to eradicate high risk backlog (Â£)',
#        'Cost to eradicate significant risk backlog (Â£)',
#        'Cost to eradicate moderate risk backlog (Â£)',
#        'Cost to eradicate low risk backlog (Â£)',
#        'Percentage of GIA surveyed using risk adjusted backlog guidance (Select)',
#        'Methodology used to review costs to eradicate backlog (Select)',
#        'Methodology used to review costs to eradicate backlog - Reason (Notes)',
#        'Investment to reduce backlog maintenance - Critical Infrastructure Risk (Â£)',
#        'Investment to reduce backlog maintenance - non Critical Infrastructure Risk (Â£)'],
#       dtype='object')

# %% [markdown]
# ### Update the function

# %%
#define a function, it takes one argument - the url of the CSV
def backlogdataonly(csvurl):
  #read in the CSV
  sitedata = pd.read_csv(csvurl, encoding = "ISO-8859-1")
  #store the first 9 column names
  keykeys = list(sitedata.keys()[0:9])
  print(keykeys)
  #loop through the keys and extract the ones with backlog in them
  backlog_keys = [key for key in sitedata.keys() if 'backlog' in key.lower()]
  #add those keys to the ones we've already stored
  bothkeys = keykeys[:9]+backlog_keys
  print(bothkeys)
  #use those to extract a subset
  backlogdf = sitedata[bothkeys]
  #reshape from wide to long
  longversion = pd.melt(backlogdf, id_vars=list(sitedata.keys()[0:9]),var_name='measure', value_name='values')
  print(longversion)
  #filter to the rows where the condition is True
  backlog_filtered = longversion.drop(longversion[[type(i) == float for i in longversion["values"]]].index)
  #.index converts that list of T/F to a list of indices
  backlog_filtered = backlog_filtered.drop(backlog_filtered[backlog_filtered['values'] == 'Not Applicable'].index)
  #remove the extra row of headers too - this time inplace
  backlog_filtered = backlog_filtered.drop(backlog_filtered[backlog_filtered['values'] == 'Cost to eradicate high risk backlog (£)'].index)
  #return the resulting dataframe to whatever called the function
  return(backlog_filtered)

# %% [markdown]
# ## To be continued in another notebook...
#
# This notebook documents the exploration of the data. With that encoded in the functions above, we start a [new notebook to apply those to multiple spreadsheets](https://colab.research.google.com/drive/1qsGhqDeIMsdeI0ydyWw2pimSOZ9PDBM1?usp=sharing).
